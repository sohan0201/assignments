# %%
#importing librararies
import numpy as np
import pandas as pd

# %%
#Question 1
df=pd.DataFrame({
    'name':['Mikku','Mayank','Lalit_bhadana','ankur'],
    'age':[21,22,25,29],
    'mail_id':['mikkujain22@gmail.com','mayankj914@gmail.com','lalitbhadana24@gmail.com','ankur222@outlook.com'],
    'phone_no':[9855722642,59822698,987554612,9775946213]
})
print(df)
# Out:
#    age                   mail_id           name    phone_no
# 0   21     mikkujain22@gmail.com          Mikku  9855722642
# 1   22      mayankj914@gmail.com         Mayank    59822698
# 2   25  lalitbhadana24@gmail.com  Lalit_bhadana   987554612
# 3   29      ankur222@outlook.com          ankur  9775946213

# %%
#Question 2
df1=pd.read_csv('wheather.csv')
print(df1.head(5))
print(df1.head(10))
df1.describe(include='all')
#df1.describe(include=['object'])
print(df1.tail(5))
print(df1['Location'])
df1['Location'].describe()
#df1.describe(include='all')
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
