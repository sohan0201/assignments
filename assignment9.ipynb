# %%
#Import liaberies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import datasets
df=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df.shape
# Out:
# (366, 24)

# %%
df.describe(include='O')
# Out:
#              Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count         366       366         363        335        365       366
# unique        366         1          16         16         16         2
# top     4/15/2008  Canberra          NW         SE         NW        No
# freq            1       366          73         47         61       300
#
#        RainTomorrow
# count           366
# unique            2
# top              No
# freq            300

# %%
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df=df.drop(['WindDir9am'],axis=1)

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         3
# WindGustDir      3
# WindGustSpeed    2
# WindDir3pm       1
# WindSpeed9am     7
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df['WindSpeed9am']=df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         3
# WindGustDir      3
# WindGustSpeed    2
# WindDir3pm       1
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df['Sunshine']=df['Sunshine'].fillna(df['Sunshine'].mean())

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      3
# WindGustSpeed    0
# WindDir3pm       1
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      3
# WindGustSpeed    0
# WindDir3pm       1
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df.WindGustDir.value_counts()
# Out:
# NW     73
# NNW    44
# E      37
# WNW    35
# ENE    30
# ESE    23
# S      22
# N      21
# W      20
# NE     16
# SE     12
# SSE    12
# NNE     8
# SSW     5
# SW      3
# WSW     2
# Name: WindGustDir, dtype: int64

# %%
df['WindDir3pm']=df['WindDir3pm'].fillna(df['WindDir3pm'].mode())

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      3
# WindGustSpeed    0
# WindDir3pm       1
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.WindGustDir=le.fit_transform(df.WindGustDir)
df.WindDir3pm=le.fit_transform(df.WindDir3pm)

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  366.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.467180
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    6.000000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustDir  WindGustSpeed  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# count   366.000000     366.000000  366.000000    366.000000    366.000000
# mean      9.248634      39.840659    8.530055      9.651811     17.986339
# std       4.366239      13.023978    4.564656      7.875308      8.856997
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df.shape
# Out:
# (366, 23)

# %%
sns.distplot(df.Temp9am)

# %%
sns.distplot(df.MaxTemp)

# %%
sns.distplot(df.MinTemp)

# %%
sns.distplot(df.Rainfall)

# %%
sns.distplot(df.Evaporation)

# %%
sns.distplot(df.Sunshine)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
Sunshine = df[df['Sunshine'] == 1]
not_Sunshine = df[df['Sunshine'] == 0]
print 'Sunshine ', Sunshine.head(), '\n\nNot Sunshine ', not_Sunshine.head()
# Out:
# Sunshine  Empty DataFrame
# Columns: [Date, Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RISK_MM, RainTomorrow]
# Index: []
#
# [0 rows x 23 columns]
#
# Not Sunshine             Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 21   11/22/2007  Canberra     16.4     19.4       0.4          9.2       0.0
# 79    1/19/2008  Canberra     15.3     19.6      18.8          5.0       0.0
# 95     2/4/2008  Canberra     18.2     22.6       1.8          8.0       0.0
# 141   3/21/2008  Canberra     13.0     14.8       0.0          8.2       0.0
# 145   3/25/2008  Canberra     13.1     17.4       6.4          2.8       0.0
#
#      WindGustDir  WindGustSpeed  WindDir3pm      ...       Humidity3pm  \
# 21             3           26.0           1      ...                72
# ...

# %%
#Adding a new columu
df['Sunshine'] = df.Humidity3pm.apply(lambda x:1 if x == 11/22/2007 else 0)

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4         0
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4         0
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8         0
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2         0
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6         0
#
#    WindGustDir  WindGustSpeed  WindDir3pm      ...       Humidity3pm  \
# 0           10           30.0           8      ...                29
# 1            4           39.0          14      ...                36
# 2           10           85.0           6      ...                69
# 3           10           54.0          14      ...                56
# 4           13           50.0           3      ...                49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#Univariate Analysis
p=sns.countplot(x='Sunshine',data=df)
p.set_xlabel('0=temp,1=Sunshine')
p.set_title('Sunshine count plot')
sns.despine()

# %%
sns.countplot(x='Humidity3pm',data=df)

# %%
sns.boxplot(y='Temp3pm',data=df)

# %%
df.Temp3pm.describe()
# Out:
# count    366.000000
# mean      19.230874
# std        6.640346
# min        5.100000
# 25%       14.150000
# 50%       18.550000
# 75%       24.000000
# max       34.500000
# Name: Temp3pm, dtype: float64

# %%
p=sns.countplot(x='RISK_MM',data=df)

# %%
#Bivariate Analysis
sns.barplot(x='MinTemp', y='MaxTemp', data=df)

# %%
sns.barplot(x='Sunshine', y='Humidity3pm', data=df)

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df)

# %%
sns.jointplot(x='MinTemp',y='MaxTemp',data=df)

# %%
#Multivariate Analysis
sns.factorplot(x='RISK_MM',y='Sunshine',hue='Humidity3pm',data=df,kind='bar')
